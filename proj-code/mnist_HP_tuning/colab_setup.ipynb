# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
# !pip install wandb

# %%
import wandb
wandb.login()
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
wandb.init(
    project="mnist-HP-tuning-final",
    tags=["mnist", "resnet18", "optimizer", "lr", "batch_size", "dropout", "weight_decay"])
config = wandb.config
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">colorful-water-14</strong> at: <a href='https://wandb.ai/mayindan-university-of-bamberg/mnist-HP-tuning-final/runs/hmx5710e' target="_blank">https://wandb.ai/mayindan-university-of-bamberg/mnist-HP-tuning-final/runs/hmx5710e</a><br> View project at: <a href='https://wandb.ai/mayindan-university-of-bamberg/mnist-HP-tuning-final' target="_blank">https://wandb.ai/mayindan-university-of-bamberg/mnist-HP-tuning-final</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250711_025342-hmx5710e\logs</code>
# Tracking run with wandb version 0.20.1
# Run data is saved locally in <code>c:\Users\Yindan\Documents\Bamberg4\xAI_proj\xAI-code\xAI-code\mnist_HP_tuning\wandb\run-20250711_153046-0cse6omu</code>
# ...

# %%
# !wandb sweep mnist_tuning_basic.yaml
# Out:
# wandb: Creating sweep from: mnist_tuning_basic.yaml
# wandb: Creating sweep with ID: 9fg4fur2
# wandb: View sweep at: https://wandb.ai/mayindan-university-of-bamberg/mnist-HP-tuning-final/sweeps/9fg4fur2
# wandb: Run sweep agent with: wandb agent mayindan-university-of-bamberg/mnist-HP-tuning-final/9fg4fur2

# %%
sweep_id = "mayindan-university-of-bamberg/mnist-HP-tuning-final/9fg4fur2"
# !wandb agent --count 20 {sweep_id}
# Out:
# [Epoch 1] Train Loss: 0.2010, Train Acc: 0.9360, Train Precision: 0.9355, Train Recall: 0.9353, Train F1: 0.9354
# wandb: Starting wandb agent 🕵️
#  VAL Classification Report:
# 2025-07-11 15:31:19,925 - wandb.wandb_agent - INFO - Running runs: []
# 2025-07-11 15:31:20,210 - wandb.wandb_agent - INFO - Agent received command: run
# Classification Report Table (with Accuracy):
# 2025-07-11 15:31:20,211 - wandb.wandb_agent - INFO - Agent starting run with config:
#        Class  Precision  Recall  F1-Score  Support  Accuracy
# 	augmentation: none
#            0       0.99    0.94      0.97     1442  0.938280
# 	batch_size: 32
#            1       0.99    0.96      0.98     1672  0.962321
# 	learning_rate: 0.003807664572408069
#            2       0.97    0.97      0.97     1504  0.966755
# 	lr_scheduler: none
#            3       0.99    0.98      0.98     1500  0.984667
# 	max_epochs: 20
#            4       0.98    0.99      0.99     1460  0.990411
# 	optimizer: adam
# ...
